# %% [markdown]
# # Figures appearing in the Algebraic Amplification paper at SIGMOD2020
# This notebook allows one to generate every real data figure appearing in the Algebraic Amplification paper at SIGMOD 2020. Becacuse certain figures are time and compute intensive, each figure is generated from cached data.
#
# Each type of experiment has its own Python module (e.g. Fig_EndtoEnd_accuracy, etc.) imported at the top of this notebook. These modules define long lists of alternative parameters used for experiments. We choose sets of parameters with metaparameters CHOICE (which choice of parameters are chosen) and VARIANT (which variant for printing results is chosen). Other parameters define control variables like whether new data is created and whether figures are displayed or exported as PDF.

# %%
import sys
sys.path.append("../")
import Fig_EndtoEnd_accuracy_realData, Fig_EndtoEnd_accuracy_realData_v2

# %%
# %matplotlib inline

# %% [markdown]
# ### Figure 7

# %% [markdown]
# ##### a

# %%
Fig_EndtoEnd_accuracy_realData.run(901, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### b

# %%
Fig_EndtoEnd_accuracy_realData.run(1001, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### c

# %%
Fig_EndtoEnd_accuracy_realData.run(1101, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### d
# The figure in the paper uses the DCE and DCEr data from experiments 407 and 408 to demonstrate the importance of choosing an appropriate lambda given a percentage f of labeled nodes (final shown in 409).

# %%
Fig_EndtoEnd_accuracy_realData_v2.run(407, show_plot=True) # Movielens lambda=1

# %%
Fig_EndtoEnd_accuracy_realData_v2.run(408, show_plot=True) # Movielens lambda=10

# %% [markdown]
# Do not run this experiment with create_data=True

# %%
Fig_EndtoEnd_accuracy_realData_v2.run(409, show_plot=True, create_pdf=True) # Movielens final

# %% [markdown]
# ##### e

# %%
Fig_EndtoEnd_accuracy_realData.run(821, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### f

# %%
Fig_EndtoEnd_accuracy_realData_v2.run(306, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### g

# %%
Fig_EndtoEnd_accuracy_realData.run(1204, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### h

# %%
Fig_EndtoEnd_accuracy_realData.run(604, show_plot=True, create_pdf=True)

# %% [markdown]
# ##### i
